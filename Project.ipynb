# %% [markdown]
# # Setting Up

# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# General notes to self:
# If PyCharm asks for Jupyter notebook token, try "jupyter notebook list" and copy down the string after "token=".

# %%
# Let's check the current working directory.
import os
os.getcwd()
# Out:
# '/Users/Shu/PycharmProjects/spring2019-solo-project-shuzhang96'

# %% [markdown]
# # Chicago Crime Dataset

# %% [markdown]
# I wanted to find some super cool dataset, but upon a quick search I didn't find anything that really stood out to me. So I am using:
# A dataset that describes crime in Chicago from 2001 to when I downloaded the dataset i.e. April 2019. (I went to college in Chicago, so I'm perhaps a little more interested in the city than most.) Note that this dataset excludes murders.
#
# I downloaded the data set from the website https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2.

# %%
# As an aside, the website provides some pretty cool interactive graphs of the data - better than I can do!
Image.open('./Crimedata_screenshot.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2536x1102 at 0x10C303F10>

# %%
# Reading in the data
url = '/Users/Shu/PycharmProjects/spring2019-solo-project-shuzhang96/Chicago_crimes_2001_present.csv'
data = pd.read_csv(url)

# %%
# Exploring what this data looks like
data.head()
# Out:
#          ID Case Number                    Date                Block  IUCR  \
# 0  11647131    JC214628  04/06/2019 11:50:00 PM    070XX S BISHOP ST  4387
# 1  11647074    JC214759  04/06/2019 11:48:00 PM     015XX S STATE ST  0810
# 2  11646977    JC214654  04/06/2019 11:47:00 PM     002XX W 103RD ST  1330
# 3  11647124    JC214791  04/06/2019 11:45:00 PM  020XX N KEDVALE AVE  0486
# 4  11647050    JC214665  04/06/2019 11:44:00 PM  041XX W BELMONT AVE  041A
#
#         Primary Type                  Description Location Description  \
# 0      OTHER OFFENSE  VIOLATE ORDER OF PROTECTION            RESIDENCE
# 1              THEFT                    OVER $500               STREET
# 2  CRIMINAL TRESPASS                      TO LAND          GAS STATION
# 3            BATTERY      DOMESTIC BATTERY SIMPLE            RESIDENCE
# 4            BATTERY          AGGRAVATED: HANDGUN               STREET
#
#    Arrest  Domestic  ...  Longitude                       Location  \
# ...

# %% [markdown]
# There are thirty columns in this data. What are they?
#
# Things that I will include:
# - Date: Day and time that the crime happened.
# - Primary Type: Primary description of the crime (e.g. theft)
# - Description: More detailed description of the crime (e.g. retail theft)
# - Location Description: Description of location where the crime happened.
# - Arrest: Was an arrest made: Y/N?
# - Domestic: Was the incident domestic-related as defined by the Illinois Domestic Violence Act?
#
#
# Things I will not look at:
# - ID: Unique number assigned to each case.
# - Block: City block where this happened.
# - IUCR: Code describing type of crime.
# - Beat: Describes beat where the incident occurred.

# %%
test = pd.read_csv('test.csv')
